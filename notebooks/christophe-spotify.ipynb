# %% [markdown]
# # Spotify API

# %%
import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import oauth2
import random
from functools import reduce
import requests
from spotify.spotify_creds import SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET, SPOTIFY_USER

# %% [markdown]
# Spotify Developer API documentation
# https://developer.spotify.com/documentation/web-api/

# %% [markdown]
# ## Authentification

# %%
# secrets
cid = SPOTIFY_CLIENT_ID
secret = SPOTIFY_CLIENT_SECRET
username = SPOTIFY_USER

# %%
# First approach
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Second approach
def spotify_authentification():
    """
    Api authentification using requests
    """
    AUTH_URL = 'https://accounts.spotify.com/api/token'

    # POST
    auth_response = requests.post(AUTH_URL, {
        'grant_type': 'client_credentials',
        'client_id': cid,
        'client_secret': secret,
    })

    # convert the response to JSON
    auth_response_data = auth_response.json()

    # save the access token
    access_token = auth_response_data['access_token']

    headers = {
        'Authorization': 'Bearer {token}'.format(token=access_token)
    }
    return headers

headers = spotify_authentification()

# %%
sp.playlist(playlist_id = '2Zbn1h9DY5rJagR2NjeRxR?si=5329ce97a256482c')
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/2Zbn1h9DY5rJagR2NjeRxR'},
#  'followers': {'href': None, 'total': 2},
#  'href': 'https://api.spotify.com/v1/playlists/2Zbn1h9DY5rJagR2NjeRxR?additional_types=track',
#  'id': '2Zbn1h9DY5rJagR2NjeRxR',
#  'images': [{'height': 640,
#    'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730c2c6e30fedd6dc367484d79ab67616d0000b2732a896bf89ee1e87f1a774cb6ab67616d0000b27363b382b8786ce29eb28783c5ab67616d0000b273fee3bed41ab4a10414396504',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730c2c6e30fedd6dc367484d79ab67616d0000b2732a896bf89ee1e87f1a774cb6ab67616d0000b27363b382b8786ce29eb28783c5ab67616d0000b273fee3bed41ab4a10414396504',
#    'width': 300},
#   {'height': 60,
#    'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730c2c6e30fedd6dc367484d79ab67616d0000b2732a896bf89ee1e87f1a774cb6ab67616d0000b27363b382b8786ce29eb28783c5ab67616d0000b273fee3bed41ab4a10414396504',
#    'width': 60}],
#  'name': 'Latin',
#  'owner': {'display_name': 'keir20',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#   'href': 'https://api.spotify.com/v1/users/keir20',
#   'id': 'keir20',
#   'type': 'user',
#   'uri': 'spotify:user:keir20'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'NDEsNmFmNDMwNDVlMjA5MjNiNjhhNWQxM2YzMzhkNTc5N2VmZDMwNTlmNw==',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/2Zbn1h9DY5rJagR2NjeRxR/tracks?offset=0&limit=100&additional_types=track',
#   'items': [{'added_at': '2019-07-08T14:22:40Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7BFnoFhJjLWcsqmN3Hizqg'},
#         'href': 'https://api.spotify.com/v1/artists/7BFnoFhJjLWcsqmN3Hizqg',
#         'id': '7BFnoFhJjLWcsqmN3Hizqg',
#         'name': 'Joe Arroyo',
#         'type': 'artist',
#         'uri': 'spotify:artist:7BFnoFhJjLWcsqmN3Hizqg'}],
#       'available_markets': ['AD',
#        'AE',
#        'AL',
#        'AM',
#        'AO',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BT',
#        'BW',
#        'BY',
#        'CA',
#        'CH',
#        'CI',
#        'CM',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DZ',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GW',
#        'HK',
#        'HR',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'ST',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UZ',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6ubTK1qVLWQSblspjFxtZn'},
#       'href': 'https://api.spotify.com/v1/albums/6ubTK1qVLWQSblspjFxtZn',
#       'id': '6ubTK1qVLWQSblspjFxtZn',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2730c2c6e30fedd6dc367484d79',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e020c2c6e30fedd6dc367484d79',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048510c2c6e30fedd6dc367484d79',
#         'width': 64}],
#       'name': '32 Cañonazos',
#       'release_date': '2015-07-01',
#       'release_date_precision': 'day',
#       'total_tracks': 32,
#       'type': 'album',
#       'uri': 'spotify:album:6ubTK1qVLWQSblspjFxtZn'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7BFnoFhJjLWcsqmN3Hizqg'},
#        'href': 'https://api.spotify.com/v1/artists/7BFnoFhJjLWcsqmN3Hizqg',
#        'id': '7BFnoFhJjLWcsqmN3Hizqg',
#        'name': 'Joe Arroyo',
#        'type': 'artist',
#        'uri': 'spotify:artist:7BFnoFhJjLWcsqmN3Hizqg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/54h3j85gGrqCsfK8D0RuUM'},
#        'href': 'https://api.spotify.com/v1/artists/54h3j85gGrqCsfK8D0RuUM',
#        'id': '54h3j85gGrqCsfK8D0RuUM',
#        'name': 'La Verdad',
#        'type': 'artist',
#        'uri': 'spotify:artist:54h3j85gGrqCsfK8D0RuUM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AM',
#       'AO',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BT',
#       'BW',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CM',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DZ',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GW',
#       'HK',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UZ',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 378373,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'COF019401017'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4sm3mdqmSqhG8KU79rVOY8'},
#      'href': 'https://api.spotify.com/v1/tracks/4sm3mdqmSqhG8KU79rVOY8',
#      'id': '4sm3mdqmSqhG8KU79rVOY8',
#      'is_local': False,
#      'name': 'Rebelión',
#      'popularity': 43,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4a66712263bdced94677a6764fdfaa0fb5e62254?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:4sm3mdqmSqhG8KU79rVOY8'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-07-08T14:25:21Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2weA6hhVqTIN2gSn9PUB9U'},
#         'href': 'https://api.spotify.com/v1/artists/2weA6hhVqTIN2gSn9PUB9U',
#         'id': '2weA6hhVqTIN2gSn9PUB9U',
#         'name': 'Celia Cruz',
#         'type': 'artist',
#         'uri': 'spotify:artist:2weA6hhVqTIN2gSn9PUB9U'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4AvzQm7Fhjj0VtEn0wehwx'},
#       'href': 'https://api.spotify.com/v1/albums/4AvzQm7Fhjj0VtEn0wehwx',
#       'id': '4AvzQm7Fhjj0VtEn0wehwx',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273e5d55d161d81f0dd9e644fd6',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02e5d55d161d81f0dd9e644fd6',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851e5d55d161d81f0dd9e644fd6',
#         'width': 64}],
#       'name': 'Celia',
#       'release_date': '2015-10-02',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:4AvzQm7Fhjj0VtEn0wehwx'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2weA6hhVqTIN2gSn9PUB9U'},
#        'href': 'https://api.spotify.com/v1/artists/2weA6hhVqTIN2gSn9PUB9U',
#        'id': '2weA6hhVqTIN2gSn9PUB9U',
#        'name': 'Celia Cruz',
#        'type': 'artist',
#        'uri': 'spotify:artist:2weA6hhVqTIN2gSn9PUB9U'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 199316,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USDBB0602784'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7m5hbyERUKJC0268b6uEZD'},
#      'href': 'https://api.spotify.com/v1/tracks/7m5hbyERUKJC0268b6uEZD',
#      'id': '7m5hbyERUKJC0268b6uEZD',
#      'is_local': False,
#      'name': 'Guantanamera',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7m5hbyERUKJC0268b6uEZD'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-07-08T15:52:24Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hCsqVHnBo1BVQWuIjRMkL'},
#         'href': 'https://api.spotify.com/v1/artists/6hCsqVHnBo1BVQWuIjRMkL',
#         'id': '6hCsqVHnBo1BVQWuIjRMkL',
#         'name': "Sergio Mendes & Brasil '66",
#         'type': 'artist',
#         'uri': 'spotify:artist:6hCsqVHnBo1BVQWuIjRMkL'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7sLtxMp2mLbxHermdVqYD0'},
#       'href': 'https://api.spotify.com/v1/albums/7sLtxMp2mLbxHermdVqYD0',
#       'id': '7sLtxMp2mLbxHermdVqYD0',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27363b382b8786ce29eb28783c5',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0263b382b8786ce29eb28783c5',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485163b382b8786ce29eb28783c5',
#         'width': 64}],
#       'name': 'Foursider',
#       'release_date': '1972-01-01',
#       'release_date_precision': 'day',
#       'total_tracks': 21,
#       'type': 'album',
#       'uri': 'spotify:album:7sLtxMp2mLbxHermdVqYD0'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hCsqVHnBo1BVQWuIjRMkL'},
#        'href': 'https://api.spotify.com/v1/artists/6hCsqVHnBo1BVQWuIjRMkL',
#        'id': '6hCsqVHnBo1BVQWuIjRMkL',
#        'name': "Sergio Mendes & Brasil '66",
#        'type': 'artist',
#        'uri': 'spotify:artist:6hCsqVHnBo1BVQWuIjRMkL'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 159466,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USAM16974747'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6YTBfxkdGce9pLEy9jG9Jo'},
#      'href': 'https://api.spotify.com/v1/tracks/6YTBfxkdGce9pLEy9jG9Jo',
#      'id': '6YTBfxkdGce9pLEy9jG9Jo',
#      'is_local': False,
#      'name': 'Mais Que Nada',
#      'popularity': 59,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6YTBfxkdGce9pLEy9jG9Jo'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-09-24T08:22:27Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6SPpCqM8gOzrtICAxN5NuX'},
#         'href': 'https://api.spotify.com/v1/artists/6SPpCqM8gOzrtICAxN5NuX',
#         'id': '6SPpCqM8gOzrtICAxN5NuX',
#         'name': 'Tito Puente',
#         'type': 'artist',
#         'uri': 'spotify:artist:6SPpCqM8gOzrtICAxN5NuX'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4jDlifFGsIq4Am1bSbCXVH'},
#       'href': 'https://api.spotify.com/v1/albums/4jDlifFGsIq4Am1bSbCXVH',
#       'id': '4jDlifFGsIq4Am1bSbCXVH',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273fee3bed41ab4a10414396504',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02fee3bed41ab4a10414396504',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851fee3bed41ab4a10414396504',
#         'width': 64}],
#       'name': 'The Latin World Of Tito Puente',
#       'release_date': '1963-12-31',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4jDlifFGsIq4Am1bSbCXVH'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6SPpCqM8gOzrtICAxN5NuX'},
#        'href': 'https://api.spotify.com/v1/artists/6SPpCqM8gOzrtICAxN5NuX',
#        'id': '6SPpCqM8gOzrtICAxN5NuX',
#        'name': 'Tito Puente',
#        'type': 'artist',
#        'uri': 'spotify:artist:6SPpCqM8gOzrtICAxN5NuX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 274751,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USDBB0601032'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2VU6lR5PVmUTXSca3pYI68'},
#      'href': 'https://api.spotify.com/v1/tracks/2VU6lR5PVmUTXSca3pYI68',
#      'id': '2VU6lR5PVmUTXSca3pYI68',
#      'is_local': False,
#      'name': 'Oye Cómo Va',
#      'popularity': 33,
#      'preview_url': None,
#      'track': True,
#      'track_number': 10,
#      'type': 'track',
#      'uri': 'spotify:track:2VU6lR5PVmUTXSca3pYI68'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-09-24T08:22:33Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11kBu957KTYoAltZHDm8gW'},
#         'href': 'https://api.spotify.com/v1/artists/11kBu957KTYoAltZHDm8gW',
#         'id': '11kBu957KTYoAltZHDm8gW',
#         'name': 'Buena Vista Social Club',
#         'type': 'artist',
#         'uri': 'spotify:artist:11kBu957KTYoAltZHDm8gW'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CW',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6DPdEaZ0KDBCCgXyy4q8bi'},
#       'href': 'https://api.spotify.com/v1/albums/6DPdEaZ0KDBCCgXyy4q8bi',
#       'id': '6DPdEaZ0KDBCCgXyy4q8bi',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2732a896bf89ee1e87f1a774cb6',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e022a896bf89ee1e87f1a774cb6',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048512a896bf89ee1e87f1a774cb6',
#         'width': 64}],
#       'name': 'Buena Vista Social Club',
#       'release_date': '1997-06-23',
#       'release_date_precision': 'day',
#       'total_tracks': 14,
#       'type': 'album',
#       'uri': 'spotify:album:6DPdEaZ0KDBCCgXyy4q8bi'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/11kBu957KTYoAltZHDm8gW'},
#        'href': 'https://api.spotify.com/v1/artists/11kBu957KTYoAltZHDm8gW',
#        'id': '11kBu957KTYoAltZHDm8gW',
#        'name': 'Buena Vista Social Club',
#        'type': 'artist',
#        'uri': 'spotify:artist:11kBu957KTYoAltZHDm8gW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 256653,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBBGU9700150'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5sbw5zIz9ck2pOEDXUR0QU'},
#      'href': 'https://api.spotify.com/v1/tracks/5sbw5zIz9ck2pOEDXUR0QU',
#      'id': '5sbw5zIz9ck2pOEDXUR0QU',
#      'is_local': False,
#      'name': 'Chan Chan',
#      'popularity': 70,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4ddf72b5a77f1baa4c8c1fcd5467940237506ec4?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5sbw5zIz9ck2pOEDXUR0QU'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-09-24T08:33:10Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LhGZbtdRFjiJg8jwmF8qW'},
#         'href': 'https://api.spotify.com/v1/artists/7LhGZbtdRFjiJg8jwmF8qW',
#         'id': '7LhGZbtdRFjiJg8jwmF8qW',
#         'name': 'Los Cuatro De Belén',
#         'type': 'artist',
#         'uri': 'spotify:artist:7LhGZbtdRFjiJg8jwmF8qW'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'JP',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'ME',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RS',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'XK',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1xTj38HDN3SQY28msX0aL8'},
#       'href': 'https://api.spotify.com/v1/albums/1xTj38HDN3SQY28msX0aL8',
#       'id': '1xTj38HDN3SQY28msX0aL8',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27342ac0b48761ace5d10ced3e1',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0242ac0b48761ace5d10ced3e1',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485142ac0b48761ace5d10ced3e1',
#         'width': 64}],
#       'name': 'Grandes Exitos De La Musica Cubana Vol. 2',
#       'release_date': '2011-07-05',
#       'release_date_precision': 'day',
#       'total_tracks': 15,
#       'type': 'album',
#       'uri': 'spotify:album:1xTj38HDN3SQY28msX0aL8'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7LhGZbtdRFjiJg8jwmF8qW'},
#        'href': 'https://api.spotify.com/v1/artists/7LhGZbtdRFjiJg8jwmF8qW',
#        'id': '7LhGZbtdRFjiJg8jwmF8qW',
#        'name': 'Los Cuatro De Belén',
#        'type': 'artist',
#        'uri': 'spotify:artist:7LhGZbtdRFjiJg8jwmF8qW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 207293,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USR011100383'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0fcQefJWt75G7bRSVnOCkB'},
#      'href': 'https://api.spotify.com/v1/tracks/0fcQefJWt75G7bRSVnOCkB',
#      'id': '0fcQefJWt75G7bRSVnOCkB',
#      'is_local': False,
#      'name': 'Suavecito',
#      'popularity': 2,
#      'preview_url': 'https://p.scdn.co/mp3-preview/ee34e7d073e2e486424808478ccf80076f157db1?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:0fcQefJWt75G7bRSVnOCkB'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-09-24T08:35:57Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LmwELEKyxDFxrbZzR8K4U'},
#         'href': 'https://api.spotify.com/v1/artists/5LmwELEKyxDFxrbZzR8K4U',
#         'id': '5LmwELEKyxDFxrbZzR8K4U',
#         'name': 'Lalo Rodriguez',
#         'type': 'artist',
#         'uri': 'spotify:artist:5LmwELEKyxDFxrbZzR8K4U'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1HokFb56IjTsfq9AmIBdUr'},
#       'href': 'https://api.spotify.com/v1/albums/1HokFb56IjTsfq9AmIBdUr',
#       'id': '1HokFb56IjTsfq9AmIBdUr',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27302aecf905960be9ced0c505e',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0202aecf905960be9ced0c505e',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485102aecf905960be9ced0c505e',
#         'width': 64}],
#       'name': 'Y La Salsa Mayor Volume 1',
#       'release_date': '2011-09-13',
#       'release_date_precision': 'day',
#       'total_tracks': 8,
#       'type': 'album',
#       'uri': 'spotify:album:1HokFb56IjTsfq9AmIBdUr'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LmwELEKyxDFxrbZzR8K4U'},
#        'href': 'https://api.spotify.com/v1/artists/5LmwELEKyxDFxrbZzR8K4U',
#        'id': '5LmwELEKyxDFxrbZzR8K4U',
#        'name': 'Lalo Rodriguez',
#        'type': 'artist',
#        'uri': 'spotify:artist:5LmwELEKyxDFxrbZzR8K4U'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 351306,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USR010612827'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5TweTq5HBOEBQBz4KH2HB6'},
#      'href': 'https://api.spotify.com/v1/tracks/5TweTq5HBOEBQBz4KH2HB6',
#      'id': '5TweTq5HBOEBQBz4KH2HB6',
#      'is_local': False,
#      'name': 'Fuimos Amigos',
#      'popularity': 12,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7134b4ca1b62b60289e000079b065bb88f189d62?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:5TweTq5HBOEBQBz4KH2HB6'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-09-24T08:36:31Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41Mi8ZudxhKAC9kLly1WCi'},
#         'href': 'https://api.spotify.com/v1/artists/41Mi8ZudxhKAC9kLly1WCi',
#         'id': '41Mi8ZudxhKAC9kLly1WCi',
#         'name': 'jose bello',
#         'type': 'artist',
#         'uri': 'spotify:artist:41Mi8ZudxhKAC9kLly1WCi'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
# ...
#        'href': 'https://api.spotify.com/v1/artists/7BFnoFhJjLWcsqmN3Hizqg',
#        'id': '7BFnoFhJjLWcsqmN3Hizqg',
#        'name': 'Joe Arroyo',
#        'type': 'artist',
#        'uri': 'spotify:artist:7BFnoFhJjLWcsqmN3Hizqg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 1,
#      'duration_ms': 309800,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'COF019501563'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/4EDdz0HOnLjBmNHkGmkFoC'},
#      'href': 'https://api.spotify.com/v1/tracks/4EDdz0HOnLjBmNHkGmkFoC',
#      'id': '4EDdz0HOnLjBmNHkGmkFoC',
#      'is_local': False,
#      'name': 'Confundido',
#      'popularity': 26,
#      'preview_url': 'https://p.scdn.co/mp3-preview/0d19c0c3f337321ebd15f6423dc3016920ff635f?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:4EDdz0HOnLjBmNHkGmkFoC'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2019-12-18T16:51:42Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cvnQ2gtwZraxeE99Y8aOg'},
#         'href': 'https://api.spotify.com/v1/artists/5cvnQ2gtwZraxeE99Y8aOg',
#         'id': '5cvnQ2gtwZraxeE99Y8aOg',
#         'name': 'Afro-Cuban All Stars',
#         'type': 'artist',
#         'uri': 'spotify:artist:5cvnQ2gtwZraxeE99Y8aOg'}],
#       'available_markets': [],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/6Fd6bROjkr6wkG1AUeZir7'},
#       'href': 'https://api.spotify.com/v1/albums/6Fd6bROjkr6wkG1AUeZir7',
#       'id': '6Fd6bROjkr6wkG1AUeZir7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273d2922dc1a09e977d603f9e43',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02d2922dc1a09e977d603f9e43',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851d2922dc1a09e977d603f9e43',
#         'width': 64}],
#       'name': 'A Toda Cuba Le Gusta',
#       'release_date': '1997-10-31',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:6Fd6bROjkr6wkG1AUeZir7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cvnQ2gtwZraxeE99Y8aOg'},
#        'href': 'https://api.spotify.com/v1/artists/5cvnQ2gtwZraxeE99Y8aOg',
#        'id': '5cvnQ2gtwZraxeE99Y8aOg',
#        'name': 'Afro-Cuban All Stars',
#        'type': 'artist',
#        'uri': 'spotify:artist:5cvnQ2gtwZraxeE99Y8aOg'}],
#      'available_markets': [],
#      'disc_number': 1,
#      'duration_ms': 395706,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBBGU9700147'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/08kX31cCxt2qVNrp5qNZB9'},
#      'href': 'https://api.spotify.com/v1/tracks/08kX31cCxt2qVNrp5qNZB9',
#      'id': '08kX31cCxt2qVNrp5qNZB9',
#      'is_local': False,
#      'name': 'Amor Verdadero',
#      'popularity': 0,
#      'preview_url': None,
#      'track': True,
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:08kX31cCxt2qVNrp5qNZB9'},
#     'video_thumbnail': {'url': None}},
#    {'added_at': '2021-02-22T16:24:03Z',
#     'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/keir20'},
#      'href': 'https://api.spotify.com/v1/users/keir20',
#      'id': 'keir20',
#      'type': 'user',
#      'uri': 'spotify:user:keir20'},
#     'is_local': False,
#     'primary_color': None,
#     'track': {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JIMhbNg4VwToE3unSL3C4'},
#         'href': 'https://api.spotify.com/v1/artists/0JIMhbNg4VwToE3unSL3C4',
#         'id': '0JIMhbNg4VwToE3unSL3C4',
#         'name': 'Bobby Cruz',
#         'type': 'artist',
#         'uri': 'spotify:artist:0JIMhbNg4VwToE3unSL3C4'}],
#       'available_markets': ['AD',
#        'AE',
#        'AG',
#        'AL',
#        'AM',
#        'AO',
#        'AR',
#        'AT',
#        'AU',
#        'AZ',
#        'BA',
#        'BB',
#        'BD',
#        'BE',
#        'BF',
#        'BG',
#        'BH',
#        'BI',
#        'BJ',
#        'BN',
#        'BO',
#        'BR',
#        'BS',
#        'BT',
#        'BW',
#        'BY',
#        'BZ',
#        'CA',
#        'CH',
#        'CI',
#        'CL',
#        'CM',
#        'CO',
#        'CR',
#        'CV',
#        'CY',
#        'CZ',
#        'DE',
#        'DJ',
#        'DK',
#        'DM',
#        'DO',
#        'DZ',
#        'EC',
#        'EE',
#        'EG',
#        'ES',
#        'FI',
#        'FJ',
#        'FM',
#        'FR',
#        'GA',
#        'GB',
#        'GD',
#        'GE',
#        'GH',
#        'GM',
#        'GN',
#        'GQ',
#        'GR',
#        'GT',
#        'GW',
#        'GY',
#        'HK',
#        'HN',
#        'HR',
#        'HT',
#        'HU',
#        'ID',
#        'IE',
#        'IL',
#        'IN',
#        'IS',
#        'IT',
#        'JM',
#        'JO',
#        'KE',
#        'KG',
#        'KH',
#        'KI',
#        'KM',
#        'KN',
#        'KR',
#        'KW',
#        'KZ',
#        'LA',
#        'LB',
#        'LC',
#        'LI',
#        'LK',
#        'LR',
#        'LS',
#        'LT',
#        'LU',
#        'LV',
#        'MA',
#        'MC',
#        'MD',
#        'MG',
#        'MH',
#        'MK',
#        'ML',
#        'MN',
#        'MO',
#        'MR',
#        'MT',
#        'MU',
#        'MV',
#        'MW',
#        'MX',
#        'MY',
#        'MZ',
#        'NA',
#        'NE',
#        'NG',
#        'NI',
#        'NL',
#        'NO',
#        'NP',
#        'NR',
#        'NZ',
#        'OM',
#        'PA',
#        'PE',
#        'PG',
#        'PH',
#        'PK',
#        'PL',
#        'PS',
#        'PT',
#        'PW',
#        'PY',
#        'QA',
#        'RO',
#        'RU',
#        'RW',
#        'SA',
#        'SB',
#        'SC',
#        'SE',
#        'SG',
#        'SI',
#        'SK',
#        'SL',
#        'SM',
#        'SN',
#        'SR',
#        'ST',
#        'SV',
#        'SZ',
#        'TD',
#        'TG',
#        'TH',
#        'TL',
#        'TN',
#        'TO',
#        'TR',
#        'TT',
#        'TV',
#        'TW',
#        'TZ',
#        'UA',
#        'UG',
#        'US',
#        'UY',
#        'UZ',
#        'VC',
#        'VN',
#        'VU',
#        'WS',
#        'ZA',
#        'ZM',
#        'ZW'],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3y6psCkk0iiyHW9RsZd1OU'},
#       'href': 'https://api.spotify.com/v1/albums/3y6psCkk0iiyHW9RsZd1OU',
#       'id': '3y6psCkk0iiyHW9RsZd1OU',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a6f429328269f18c92a4611a',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a6f429328269f18c92a4611a',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a6f429328269f18c92a4611a',
#         'width': 64}],
#       'name': '40 Aniversario: EN VIVO',
#       'release_date': '2004',
#       'release_date_precision': 'year',
#       'total_tracks': 42,
#       'type': 'album',
#       'uri': 'spotify:album:3y6psCkk0iiyHW9RsZd1OU'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0JIMhbNg4VwToE3unSL3C4'},
#        'href': 'https://api.spotify.com/v1/artists/0JIMhbNg4VwToE3unSL3C4',
#        'id': '0JIMhbNg4VwToE3unSL3C4',
#        'name': 'Bobby Cruz',
#        'type': 'artist',
#        'uri': 'spotify:artist:0JIMhbNg4VwToE3unSL3C4'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/33nZie2hFLgUG9gUfjTRoq'},
#        'href': 'https://api.spotify.com/v1/artists/33nZie2hFLgUG9gUfjTRoq',
#        'id': '33nZie2hFLgUG9gUfjTRoq',
#        'name': 'Ricardo Ray',
#        'type': 'artist',
#        'uri': 'spotify:artist:33nZie2hFLgUG9gUfjTRoq'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mX1TP27ndNVthqdB95bMf'},
#        'href': 'https://api.spotify.com/v1/artists/1mX1TP27ndNVthqdB95bMf',
#        'id': '1mX1TP27ndNVthqdB95bMf',
#        'name': 'Richie Ray',
#        'type': 'artist',
#        'uri': 'spotify:artist:1mX1TP27ndNVthqdB95bMf'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7Gkr47aENhNsnuE72IIuUl'},
#        'href': 'https://api.spotify.com/v1/artists/7Gkr47aENhNsnuE72IIuUl',
#        'id': '7Gkr47aENhNsnuE72IIuUl',
#        'name': 'Luisito Carrion',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Gkr47aENhNsnuE72IIuUl'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7opp16lU7VM3l2WBdGMYHP'},
#        'href': 'https://api.spotify.com/v1/artists/7opp16lU7VM3l2WBdGMYHP',
#        'id': '7opp16lU7VM3l2WBdGMYHP',
#        'name': 'Héctor Lavoe',
#        'type': 'artist',
#        'uri': 'spotify:artist:7opp16lU7VM3l2WBdGMYHP'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/09947uhj2ZwU9mFXK5v50o'},
#        'href': 'https://api.spotify.com/v1/artists/09947uhj2ZwU9mFXK5v50o',
#        'id': '09947uhj2ZwU9mFXK5v50o',
#        'name': 'Johnny Pacheco',
#        'type': 'artist',
#        'uri': 'spotify:artist:09947uhj2ZwU9mFXK5v50o'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5pUnaPzP3a5oHMWgJHU0gp'},
#        'href': 'https://api.spotify.com/v1/artists/5pUnaPzP3a5oHMWgJHU0gp',
#        'id': '5pUnaPzP3a5oHMWgJHU0gp',
#        'name': 'Marc Anthony',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pUnaPzP3a5oHMWgJHU0gp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7vBicXCUm81QrCyx83xEfj'},
#        'href': 'https://api.spotify.com/v1/artists/7vBicXCUm81QrCyx83xEfj',
#        'id': '7vBicXCUm81QrCyx83xEfj',
#        'name': 'Papo Lucca',
#        'type': 'artist',
#        'uri': 'spotify:artist:7vBicXCUm81QrCyx83xEfj'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gNP6xGmxzC25B3Fhqg5eg'},
#        'href': 'https://api.spotify.com/v1/artists/5gNP6xGmxzC25B3Fhqg5eg',
#        'id': '5gNP6xGmxzC25B3Fhqg5eg',
#        'name': 'Pedro Brull',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gNP6xGmxzC25B3Fhqg5eg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7FjTUD6W5stHN4LwBCcwkU'},
#        'href': 'https://api.spotify.com/v1/artists/7FjTUD6W5stHN4LwBCcwkU',
#        'id': '7FjTUD6W5stHN4LwBCcwkU',
#        'name': 'Wille Colon',
#        'type': 'artist',
#        'uri': 'spotify:artist:7FjTUD6W5stHN4LwBCcwkU'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7nJ3uKCT4lPwDJSRZzBlss'},
#        'href': 'https://api.spotify.com/v1/artists/7nJ3uKCT4lPwDJSRZzBlss',
#        'id': '7nJ3uKCT4lPwDJSRZzBlss',
#        'name': 'Bobby Valentin',
#        'type': 'artist',
#        'uri': 'spotify:artist:7nJ3uKCT4lPwDJSRZzBlss'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'disc_number': 2,
#      'duration_ms': 835268,
#      'episode': False,
#      'explicit': False,
#      'external_ids': {'isrc': 'USMRE0803821'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0wXEfdZOZuxpZqTRqLpBHt'},
#      'href': 'https://api.spotify.com/v1/tracks/0wXEfdZOZuxpZqTRqLpBHt',
#      'id': '0wXEfdZOZuxpZqTRqLpBHt',
#      'is_local': False,
#      'name': 'María Cervantes',
#      'popularity': 4,
#      'preview_url': 'https://p.scdn.co/mp3-preview/4d0518b79920101e1dfd6a75ffd9818614217d7a?cid=926ada51c024455f8534e0082426a8a8',
#      'track': True,
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:0wXEfdZOZuxpZqTRqLpBHt'},
#     'video_thumbnail': {'url': None}}],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 38},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:2Zbn1h9DY5rJagR2NjeRxR'}

# %% [markdown]
# ## Artist track features

# %%
def artist_track_features(artist = 'Monolink'):
    """
    This function will provide us with a dataframe with all sounds of an artist 
    and their underlying features.
    
    Inputs :
    artist = <Name of the artist>
    
    Outputs :
    > Dataframe containing the sounds of an artist
    """
    # Fetch artist tracks
    d = {}
    track_results = sp.search(q=artist, type='track',limit=50)
    for i, t in enumerate(track_results['tracks']['items']):
        track_id = t['id']
        if track_id not in d:
            d[track_id] = {'artist_feature' : t['artists'][0]['name'],
                           'query' : artist,
                           'track_name' : t['name'],
                           'popularity': t['popularity']}    
            d[track_id].update(sp.audio_features(d.keys())[0])
            
            # add genres
            headers = spotify_authentification()
            BASE_URL = 'https://api.spotify.com/v1/'
            re = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers).json()
            if re != None :
                layer = requests.get(re['artists'][0]['href'], headers=headers).json()
                if 'genres' in layer.keys():
                    d[track_id].update({'genres':layer['genres']})
                else :
                    d[track_id].update({'genres':'None'})
    return pd.DataFrame.from_dict(d, orient='index')

# %%
track_dataframe = artist_track_features('Bicep')
track_dataframe.head()
# Out:
#                        artist_feature  query track_name  popularity  \
# 0LiXd8DgPozcJVQq3QceEh          TR/ST  Bicep      Bicep          47
# 2aJDlirz6v2a4HREki98cP          Bicep  Bicep       Glue          70
# 0WfOuXw05LJq4ik1lVvTzi          Bicep  Bicep   Apricots          63
# 73X9X7kDgsm4YeHpc8prf6          Bicep  Bicep   Apricots          65
# 0HZtVLVL6oLU9WobKQxqGu          Bicep  Bicep       Lido          56
#
#                         danceability  energy  key  loudness  mode  \
# 0LiXd8DgPozcJVQq3QceEh         0.634   0.869    1     -7.34     1
# 2aJDlirz6v2a4HREki98cP         0.634   0.869    1     -7.34     1
# 0WfOuXw05LJq4ik1lVvTzi         0.634   0.869    1     -7.34     1
# 73X9X7kDgsm4YeHpc8prf6         0.634   0.869    1     -7.34     1
# 0HZtVLVL6oLU9WobKQxqGu         0.634   0.869    1     -7.34     1
#
#                         speechiness  ...  valence    tempo            type  \
# 0LiXd8DgPozcJVQq3QceEh       0.0383  ...    0.266  108.002  audio_features
# 2aJDlirz6v2a4HREki98cP       0.0383  ...    0.266  108.002  audio_features
# 0WfOuXw05LJq4ik1lVvTzi       0.0383  ...    0.266  108.002  audio_features
# 73X9X7kDgsm4YeHpc8prf6       0.0383  ...    0.266  108.002  audio_features
# 0HZtVLVL6oLU9WobKQxqGu       0.0383  ...    0.266  108.002  audio_features
#
#                                             id  \
# 0LiXd8DgPozcJVQq3QceEh  0LiXd8DgPozcJVQq3QceEh
# 2aJDlirz6v2a4HREki98cP  0LiXd8DgPozcJVQq3QceEh
# 0WfOuXw05LJq4ik1lVvTzi  0LiXd8DgPozcJVQq3QceEh
# 73X9X7kDgsm4YeHpc8prf6  0LiXd8DgPozcJVQq3QceEh
# 0HZtVLVL6oLU9WobKQxqGu  0LiXd8DgPozcJVQq3QceEh
#
#                                                          uri  \
# 0LiXd8DgPozcJVQq3QceEh  spotify:track:0LiXd8DgPozcJVQq3QceEh
# 2aJDlirz6v2a4HREki98cP  spotify:track:0LiXd8DgPozcJVQq3QceEh
# 0WfOuXw05LJq4ik1lVvTzi  spotify:track:0LiXd8DgPozcJVQq3QceEh
# 73X9X7kDgsm4YeHpc8prf6  spotify:track:0LiXd8DgPozcJVQq3QceEh
# 0HZtVLVL6oLU9WobKQxqGu  spotify:track:0LiXd8DgPozcJVQq3QceEh
#
#                                                                track_href  \
# 0LiXd8DgPozcJVQq3QceEh  https://api.spotify.com/v1/tracks/0LiXd8DgPozc...
# 2aJDlirz6v2a4HREki98cP  https://api.spotify.com/v1/tracks/0LiXd8DgPozc...
# 0WfOuXw05LJq4ik1lVvTzi  https://api.spotify.com/v1/tracks/0LiXd8DgPozc...
# 73X9X7kDgsm4YeHpc8prf6  https://api.spotify.com/v1/tracks/0LiXd8DgPozc...
# 0HZtVLVL6oLU9WobKQxqGu  https://api.spotify.com/v1/tracks/0LiXd8DgPozc...
#
#                                                              analysis_url  \
# 0LiXd8DgPozcJVQq3QceEh  https://api.spotify.com/v1/audio-analysis/0LiX...
# 2aJDlirz6v2a4HREki98cP  https://api.spotify.com/v1/audio-analysis/0LiX...
# 0WfOuXw05LJq4ik1lVvTzi  https://api.spotify.com/v1/audio-analysis/0LiX...
# 73X9X7kDgsm4YeHpc8prf6  https://api.spotify.com/v1/audio-analysis/0LiX...
# 0HZtVLVL6oLU9WobKQxqGu  https://api.spotify.com/v1/audio-analysis/0LiX...
#
#                        duration_ms time_signature  \
# 0LiXd8DgPozcJVQq3QceEh      277133              4
# 2aJDlirz6v2a4HREki98cP      277133              4
# 0WfOuXw05LJq4ik1lVvTzi      277133              4
# 73X9X7kDgsm4YeHpc8prf6      277133              4
# 0HZtVLVL6oLU9WobKQxqGu      277133              4
#
#                                                                    genres
# 0LiXd8DgPozcJVQq3QceEh  [alternative dance, art pop, canadian electrop...
# 2aJDlirz6v2a4HREki98cP                       [ambient house, electronica]
# 0WfOuXw05LJq4ik1lVvTzi                       [ambient house, electronica]
# 73X9X7kDgsm4YeHpc8prf6                       [ambient house, electronica]
# 0HZtVLVL6oLU9WobKQxqGu                       [ambient house, electronica]
#
# [5 rows x 23 columns]

# %%
track_dataframe.columns

# %% [markdown]
# ## Get playlist features

# %% [markdown]
# 📌 Change non-regular artists KeyError

# %%
def playlist_track_features(playlist_id = '501WYBYmwFxO4sZfY2ZimM'):
    '''
    Function that retrieving songs and the underlying features from a spotify playlist
    input : playlist_id
    output : Dataframe with features of a song [Dancabiliy, etc..]
    '''
    # base URL of all Spotify API endpoints
    BASE_URL = 'https://api.spotify.com/v1/'

    # actual GET request with proper header
    headers = spotify_authentification()
    r = requests.get(BASE_URL + 'playlists/' + playlist_id + '/tracks', headers=headers).json()
    d = {}
    for track in range(len(r['items'])):
        content = r['items'][track]['track']
        track_id = content['id']
        if track_id != None:
            if track_id not in d:
                d[track_id] = {'artist_feature' : content['artists'][0]['name'],
                               'track_name' : content['name'],
                               'popularity': content['popularity']} 
                d[track_id].update(sp.audio_features(track_id)[0])

                # add genres
                headers = spotify_authentification()
                re = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers).json()
                layer = requests.get(re['artists'][0]['href'], headers=headers).json()
                if 'genres' in layer.keys():
                    d[track_id].update({'genres':layer['genres']})
                else :
                    d[track_id].update({'genres':'None'})

    df = pd.DataFrame.from_dict(d, orient='index')
    return df

# %%
df = playlist_track_features(playlist_id = '501WYBYmwFxO4sZfY2ZimM')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-1710eae92add> in <module>
# ----> 1 df = playlist_track_features(playlist_id = '501WYBYmwFxO4sZfY2ZimM')
#       2 df.head()
#
# <ipython-input-17-a5e9760fb56d> in playlist_track_features(playlist_id)
#      25                 headers = spotify_authentification()
#      26                 re = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers).json()
# ---> 27                 layer = requests.get(re['artists'][0]['href'], headers=headers).json()
#      28                 if 'genres' in layer.keys():
#      29                     d[track_id].update({'genres':layer['genres']})
#
# KeyError: 'artists'

# %%
test = requests.get('https://api.spotify.com/v1/audio-analysis/7qHFYjFaYfk5HEV5rpZKDT', headers=headers).json()
test

# %%
test.keys()

# %% [markdown]
# ## Playlist by names

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
def playlist_names(genre='alternative-rock'):
    base_url = "https://www.indieshuffle.com/playlists/genre/"
    url = f"{base_url}/{genre}"
  
    html = urlopen(url)
    soup = BeautifulSoup(html, 'lxml')
    playlist_titles = soup.find_all('h5', attrs={"class":"mrg-bottom-10"})
    
    names = []
    for playlist in range(len(playlist_titles)):
        title = playlist_titles[playlist].text
        title = title.replace('\n', '')
        names.append(title)
        print(title)
    return names

# %% [markdown]
# ## Extra features

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-analysis/' + track_id, headers=headers)
r.json()

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'tracks/' + track_id, headers=headers).json()
requests.get(r['artists'][0]['href'], headers=headers).json()['genres']

# %%
requests.get(r['artists'][0]['href'], headers=headers).json()['genres']

# %%
r['artists'][0]['href']

# %%
r

# %% [markdown]
# # Playground

# %%
content.columns

# %%
features = ['artist_feature','track_name','track_name', 'popularity', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo','type','duration_ms', 'time_signature',
       'genres']

# %%
df = content[features]

# %%
df = df[['danceability', 'energy','speechiness', 'acousticness',
       'instrumentalness', 'liveness']]

# %%
df.describe()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

categories = list(df)
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(size=12)
plt.ylim(0, 1)
ax.set_rlabel_position(10)
ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.8)

plt.show()

# %% [markdown]
# # User to user recommendation

# %%
def get_user_tracks(user_name = 'cedricrenel'):
    '''
    Retrieves a users tracks based on his publicly available playlist
    input : spotify user_name
    output : dataframe containing a users songs and the songs features
    '''
    # Authentification
    headers = spotify_authentification()
    re = requests.get(f'https://api.spotify.com/v1/users/{user_name}/playlists', headers=headers).json()
    
    # Playlist id's
    playlist_ids = []
    names = []
    for i in range(len(re['items'])):
        playlist_ids.append(re['items'][i]['id'])
        names.append(re['items'][i]['name'])
    
    # Get song features
    for i, playlist in enumerate(playlist_ids):
        if i == 0:
            df = playlist_track_features(playlist)
            print(f"[{round(i/len(names) *100)} %] Playlist : {names[i]} ✔")
        else :
            new_df = playlist_track_features(playlist)
            df = pd.concat([df, new_df])
            print(f"[{round(i/len(names) *100)} %] Playlist : {names[i]} ✔")
    return df

# %%
toff = get_user_tracks(user_name = 'toff-93')

# %%
toff['genres'][3]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()

# %%
[x.replace(' ', '') for x in toff['genres'][3]]

# %%
[x.strip(' ') for x in toff['genres'][3]]

# %%
def clean_genres(liste):
    liste = [x.replace(' ', '') for x in liste]
    liste = ", ".join(liste)
    return liste

# %%
toff['clean_genres'] = toff['genres'].apply(clean_genres)

# %%
toff.shape

# %%
", ".join(toff['genres'][3])

# %%
ce = get_user_tracks(user_name = 'cedricrenel')

# %%
ce
